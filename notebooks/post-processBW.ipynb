# %%
# !pip install pandas
# !pip install pyproj
# !pip install seaborn
# !pip install ipywidgets
from apeiron.run import Run, Scenario
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import ipywidgets as widgets
import glob
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %% [markdown]
# # Select the run

# %%
scenarios_folders = glob.glob('../../dataset_symlink/*')
run_folder = ''
def f(scenarios):
    global run_folder
    run_folder = scenarios
    return scenarios

widgets.interact(f, scenarios=scenarios_folders);
# Out:
# interactive(children=(Dropdown(description='scenarios', options=('../../dataset_symlink/IND-1_run-02_02_2024_1…

# %%
r = Run(run_folder, Scenario.OPEN_FIELD)
# Out:
# ../../dataset_symlink/IND-3_run-02_02_2024_15_07_19/px4_csvlogs/*vehicle_local_position_0.csv
# /home/nunzio/lavoro/hexa-collect/post_processing/notebooks/apeiron/net.py:30: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   self.df = pd.read_csv(filename, sep = "\s+|\t+|\s+\t+|\t+\s+")

# %%
x,y,BW = r.compute_bw_xy(25)
sns.heatmap(BW)
# Out:
# <Axes: >

# %%
plt.plot(r.merged_df.y, r.merged_df.x)
# set plt axis equal
plt.axis('equal')
# Out:
# (-5.888833962078206, 123.66551320364233, -1.925894873868674, 40.44379235124215)

# %%
r.compute_throughput()

# compute mean of rtt_val

r.merged_df['rtt_val'].mean()
# Out:
# 184.27100000000002
